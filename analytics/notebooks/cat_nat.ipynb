# %%
import duckdb
import pandas as pd
import os

# %%
df_epci = duckdb.read_csv("./data/raw/perimetre-epci-a-fp.csv", sep=";",ignore_errors=True)
df_epci
# Out:
# ┌─────────┬───────────┬────────────────────────────────────┬──────────────────┬─────────────┬────────────┬───────────────┬───────────────┬─────────┬─────────┬──────────────┬────────────────────────┬───────────┬───────────┐
# │  dept   │   siren   │           raison_sociale           │ nature_juridique │ mode_financ │ nb_membres │ total_pop_tot │ total_pop_mun │ dep_com │  insee  │ siren_membre │       nom_membre       │ ptot_2025 │ pmun_2025 │
# │ varchar │   int64   │              varchar               │     varchar      │   varchar   │   int64    │    varchar    │    varchar    │ varchar │ varchar │    int64     │        varchar         │  varchar  │  varchar  │
# ├─────────┼───────────┼────────────────────────────────────┼──────────────────┼─────────────┼────────────┼───────────────┼───────────────┼─────────┼─────────┼──────────────┼────────────────────────┼───────────┼───────────┤
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01304   │    210103040 │ Pont-d'Ain             │ 2 912     │ 2 862     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01199   │    210101994 │ Jujurieux              │ 2 246     │ 2 209     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01363   │    210103636 │ Saint-Jean-le-Vieux    │ 1 873     │ 1 799     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01314   │    210103149 │ Priay                  │ 1 826     │ 1 803     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01273   │    210102737 │ Neuville-sur-Ain       │ 1 823     │ 1 798     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01303   │    210103032 │ Poncin                 │ 1 792     │ 1 766     │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01068   │    210100681 │ Cerdon                 │ 771       │ 755       │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01430   │    210104303 │ Varambon               │ 675       │ 664       │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01200   │    210102000 │ Labalme                │ 213       │ 207       │
# │ 01      │ 200029999 │ CC Rives de l'Ain - Pays du Cerdon │ CC               │ FPU         │         14 │ 15 156        │ 14 873        │ 01      │ 01331   │    210103313 │ Saint-Alban            │ 196       │ 195       │
# │ ·       │     ·     │      ·                             │ ·                │  ·          │          · │   ·           │   ·           │ ·       │   ·     │        ·     │    ·                   │  ·        │  ·        │
# │ ·       │     ·     │      ·                             │ ·                │  ·          │          · │   ·           │   ·           │ ·       │   ·     │        ·     │    ·                   │  ·        │  ·        │
# │ ·       │     ·     │      ·                             │ ·                │  ·          │          · │   ·           │   ·           │ ·       │   ·     │        ·     │    ·                   │  ·        │  ·        │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58121   │    215801218 │ Garchizy               │ 3 703     │ 3 666     │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58214   │    215802141 │ Pougues-les-Eaux       │ 2 434     │ 2 388     │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58051   │    215800517 │ Challuy                │ 1 620     │ 1 468     │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58278   │    215802786 │ Sermoise-sur-Loire     │ 1 543     │ 1 490     │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58207   │    215802075 │ Parigny-les-Vaux       │ 994       │ 965       │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58124   │    215801242 │ Germigny-sur-Loire     │ 762       │ 748       │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58126   │    215801267 │ Gimouille              │ 427       │ 414       │
# │ 58      │ 245804406 │ CA de Nevers                       │ CA               │ FPU         │         14 │ 69 173        │ 67 408        │ 58      │ 58225   │    215802257 │ Saincaize-Meauce       │ 366       │ 364       │
# │ 58      │ 245804497 │ CC du Nivernais Bourbonnais        │ CC               │ FPU         │          9 │ 5 266         │ 5 176         │ 58      │ 58057   │    215800574 │ Chantenay-Saint-Imbert │ 1 114     │ 1 090     │
# │ 58      │ 245804497 │ CC du Nivernais Bourbonnais        │ CC               │ FPU         │          9 │ 5 266         │ 5 176         │ 58      │ 58144   │    215801440 │ Livry                  │ 660       │ 646       │
# ├─────────┴───────────┴────────────────────────────────────┴──────────────────┴─────────────┴────────────┴───────────────┴───────────────┴─────────┴─────────┴──────────────┴────────────────────────┴───────────┴───────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                   14 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
query_epci = """
SELECT 
    DISTINCT siren,
    dept,
    TRY_CAST(REPLACE(total_pop_tot,' ','') AS DOUBLE) AS total_pop_tot,
    nb_membres
FROM df_epci
WHERE total_pop_tot IS NOT NULL
ORDER BY siren
"""

df_epci_filtered = duckdb.sql(query_epci)
df_epci_filtered
# Out:
# ┌───────────┬─────────┬───────────────┬────────────┐
# │   siren   │  dept   │ total_pop_tot │ nb_membres │
# │   int64   │ varchar │    double     │   int64    │
# ├───────────┼─────────┼───────────────┼────────────┤
# │ 200000172 │ 74      │       29204.0 │          7 │
# │ 200000438 │ 44      │       37415.0 │          9 │
# │ 200000545 │ 10      │       19206.0 │          6 │
# │ 200000628 │ 84      │       24753.0 │          5 │
# │ 200000800 │ 41      │       10410.0 │          6 │
# │ 200000925 │ 21      │       22568.0 │         22 │
# │ 200000933 │ 18      │       14561.0 │         14 │
# │ 200004802 │ 83      │       30281.0 │          9 │
# │ 200005932 │ 45      │       15994.0 │          7 │
# │ 200005957 │ 88      │       13184.0 │         30 │
# │     ·     │ ·       │          ·    │          · │
# │     ·     │ ·       │          ·    │          · │
# │     ·     │ ·       │          ·    │          · │
# │ 249720053 │ 972     │      116446.0 │         12 │
# │ 249720061 │ 972     │      151772.0 │          4 │
# │ 249730037 │ 973     │       98941.0 │          8 │
# │ 249730045 │ 973     │      153249.0 │          6 │
# │ 249730052 │ 973     │        8895.0 │          4 │
# │ 249740077 │ 974     │      185848.0 │          6 │
# │ 249740085 │ 974     │      134764.0 │          4 │
# │ 249740093 │ 974     │      130245.0 │          6 │
# │ 249740101 │ 974     │      221532.0 │          5 │
# │ 249740119 │ 974     │      218801.0 │          3 │
# ├───────────┴─────────┴───────────────┴────────────┤
# │ 1255 rows (20 shown)                   4 columns │
# └──────────────────────────────────────────────────┘

# %%
df_com = duckdb.read_csv("./data/processed/communes-france-2025-processed.csv",sep=",")
df_com
# Out:
# ┌────────────┬─────────────────────────┬─────────────────────────┬──────────┬──────────────────────┬──────────┬──────────────┬───────────┬───────────────────────────────────────────┬────────────┬────────────────┬─────────────────┐
# │ code_insee │      nom_standard       │     nom_sans_accent     │ reg_code │       reg_nom        │ dep_code │   dep_nom    │ epci_code │                 epci_nom                  │ population │ superficie_km2 │ densite_hab_km2 │
# │  varchar   │         varchar         │         varchar         │  int64   │       varchar        │ varchar  │   varchar    │  varchar  │                  varchar                  │   int64    │     int64      │     double      │
# ├────────────┼─────────────────────────┼─────────────────────────┼──────────┼──────────────────────┼──────────┼──────────────┼───────────┼───────────────────────────────────────────┼────────────┼────────────────┼─────────────────┤
# │ 01001      │ L'Abergement-Clémenciat │ l-abergement-clemenciat │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200069193 │ CC de la Dombes                           │        832 │             16 │            53.0 │
# │ 01002      │ L'Abergement-de-Varey   │ l-abergement-de-varey   │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 240100883 │ CC de la Plaine de l'Ain                  │        267 │              9 │            29.0 │
# │ 01004      │ Ambérieu-en-Bugey       │ amberieu-en-bugey       │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 240100883 │ CC de la Plaine de l'Ain                  │      14854 │             24 │           607.0 │
# │ 01005      │ Ambérieux-en-Dombes     │ amberieux-en-dombes     │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200042497 │ CC Dombes Saône Vallée                    │       1897 │             16 │           118.0 │
# │ 01006      │ Ambléon                 │ ambleon                 │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200040350 │ CC Bugey Sud                              │        113 │              6 │            19.0 │
# │ 01007      │ Ambronay                │ ambronay                │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 240100883 │ CC de la Plaine de l'Ain                  │       2833 │             34 │            84.0 │
# │ 01008      │ Ambutrix                │ ambutrix                │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 240100883 │ CC de la Plaine de l'Ain                  │        768 │              5 │           148.0 │
# │ 01009      │ Andert-et-Condon        │ andert-et-condon        │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200040350 │ CC Bugey Sud                              │        322 │              7 │            46.0 │
# │ 01010      │ Anglefort               │ anglefort               │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200070852 │ CC Usses et Rhône                         │       1125 │             29 │            38.0 │
# │ 01011      │ Apremont                │ apremont                │       84 │ Auvergne-Rhône-Alpes │ 01       │ Ain          │ 200042935 │ CA Haut - Bugey Agglomération             │        383 │             15 │            25.0 │
# │   ·        │    ·                    │    ·                    │        · │          ·           │ ·        │  ·           │     ·     │               ·                           │         ·  │              · │              ·  │
# │   ·        │    ·                    │    ·                    │        · │          ·           │ ·        │  ·           │     ·     │               ·                           │         ·  │              · │              ·  │
# │   ·        │    ·                    │    ·                    │        · │          ·           │ ·        │  ·           │     ·     │               ·                           │         ·  │              · │              ·  │
# │ 28113      │ Coulombs                │ coulombs                │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200069953 │ CC des Portes Euréliennes d'Île-de-France │       1331 │             13 │           105.0 │
# │ 28114      │ Courbehaye              │ courbehaye              │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200070159 │ CC Cœur de Beauce                         │        136 │             20 │             7.0 │
# │ 28116      │ Courville-sur-Eure      │ courville-sur-eure      │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200058360 │ CC entre Beauce et Perche                 │       2806 │             11 │           251.0 │
# │ 28117      │ Crécy-Couvé             │ crecy-couve             │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200040277 │ CA Agglo du Pays de Dreux                 │        270 │              7 │            40.0 │
# │ 28118      │ Croisilles              │ croisilles              │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200069953 │ CC des Portes Euréliennes d'Île-de-France │        424 │              6 │            73.0 │
# │ 28119      │ La Croix-du-Perche      │ la-croix-du-perche      │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200070167 │ CC Terres de Perche                       │        148 │             13 │            12.0 │
# │ 28120      │ Crucey-Villages         │ crucey-villages         │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200040277 │ CA Agglo du Pays de Dreux                 │        445 │             44 │            10.0 │
# │ 28121      │ Dambron                 │ dambron                 │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200070159 │ CC Cœur de Beauce                         │        105 │             12 │             9.0 │
# │ 28122      │ Dammarie                │ dammarie                │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200033181 │ CA Chartres Métropole                     │       1495 │             33 │            46.0 │
# │ 28123      │ Dampierre-sous-Brou     │ dampierre-sous-brou     │       24 │ Centre-Val de Loire  │ 28       │ Eure-et-Loir │ 200069961 │ CC du Grand Châteaudun                    │        447 │             15 │            31.0 │
# ├────────────┴─────────────────────────┴─────────────────────────┴──────────┴──────────────────────┴──────────┴──────────────┴───────────┴───────────────────────────────────────────┴────────────┴────────────────┴─────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                           12 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
query = """
SELECT 
    epci_code,
    sum(superficie_km2) AS superficie_km2
FROM df_com
WHERE (superficie_km2 IS NOT NULL) AND (epci_code != 'ZZZZZZZZZ')
GROUP BY epci_code
"""

df_surface_epci = duckdb.sql(query)
df_surface_epci
# Out:
# ┌───────────┬────────────────┐
# │ epci_code │ superficie_km2 │
# │  varchar  │     int128     │
# ├───────────┼────────────────┤
# │ 200040350 │            437 │
# │ 200071751 │           1208 │
# │ 200070308 │            300 │
# │ 240200501 │            369 │
# │ 200040426 │            330 │
# │ 200070985 │            265 │
# │ 240300491 │            333 │
# │ 240300657 │            380 │
# │ 200071512 │            733 │
# │ 200071884 │            917 │
# │     ·     │             ·  │
# │     ·     │             ·  │
# │     ·     │             ·  │
# │ 249000241 │            175 │
# │ 200057859 │            132 │
# │ 249100546 │            192 │
# │ 200056380 │             76 │
# │ 200058485 │             85 │
# │ 249710070 │            342 │
# │ 249710047 │            160 │
# │ 249720061 │            176 │
# │ 249730045 │           4860 │
# │ 249740119 │            289 │
# ├───────────┴────────────────┤
# │    1255 rows (20 shown)    │
# └────────────────────────────┘

# %%
query = """
SELECT 
    df_epci_filtered.*,
    df_surface_epci.superficie_km2
FROM df_epci_filtered
LEFT JOIN df_surface_epci
ON df_epci_filtered.siren = df_surface_epci.epci_code
"""

df_epci_filtered = duckdb.sql(query)

# %%
df_cat_nat = duckdb.read_csv("./data/raw/cat_nat.csv",skiprows=2)
df_cat_nat
# Out:
# ┌───────────┬────────────────────────────────────────────────────────────┬─────────────────────────────────────────────────────────────┐
# │   Code    │                          Libellé                           │ Nombre d'Arrêtés de Catastrophes Naturelles publiés au J.O. │
# │   int64   │                          varchar                           │                            int64                            │
# ├───────────┼────────────────────────────────────────────────────────────┼─────────────────────────────────────────────────────────────┤
# │ 200000172 │ CC Faucigny - Glières                                      │                                                          58 │
# │ 200000438 │ CC du Pays de Pontchâteau St-Gildas-des-Bois               │                                                          45 │
# │ 200000545 │ CC des Portes de Romilly sur Seine                         │                                                          31 │
# │ 200000628 │ CC Rhône Lez Provence                                      │                                                          87 │
# │ 200000800 │ CC Coeur de Sologne                                        │                                                          31 │
# │ 200000925 │ CC de la Plaine Dijonnaise                                 │                                                          91 │
# │ 200000933 │ CC Sauldre et Sologne                                      │                                                         111 │
# │ 200004802 │ CC du Pays de Fayence                                      │                                                         111 │
# │ 200005932 │ CC des Portes de Sologne                                   │                                                          62 │
# │ 200005957 │ CC de la Région de Rambervillers                           │                                                         219 │
# │     ·     │               ·                                            │                                                           · │
# │     ·     │               ·                                            │                                                           · │
# │     ·     │               ·                                            │                                                           · │
# │ 249720061 │ CA du Centre de la Martinique                              │                                                          89 │
# │ 249730037 │ CC de l'Ouest Guyanais                                     │                                                           9 │
# │ 249730045 │ CA du Centre Littoral                                      │                                                          30 │
# │ 249730052 │ CC de l'Est Guyanais                                       │                                                           2 │
# │ 249740077 │ CA CIVIS (Communauté Intercommunale des Villes Solidaires) │                                                         144 │
# │ 249740085 │ CA du Sud                                                  │                                                          83 │
# │ 249740093 │ CA Intercommunale de la Réunion Est (CIREST)               │                                                         110 │
# │ 249740101 │ CA Territoire de la Côte Ouest (TCO)                       │                                                          92 │
# │ 249740119 │ CA Intercommunale du Nord de la Réunion (CINOR)            │                                                          80 │
# │     75056 │ Paris                                                      │                                                          22 │
# ├───────────┴────────────────────────────────────────────────────────────┴─────────────────────────────────────────────────────────────┤
# │ 1266 rows (20 shown)                                                                                                       3 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
mapping = {
    "Code": "siren",
    "Libellé": "nom_epci",
    "Nombre d'Arrêtés de Catastrophes Naturelles publiés au J.O.": "nb_cat_nat"
}

df_cat_nat = df_cat_nat.df()  # conversion DuckDB → pandas
df_cat_nat = df_cat_nat.rename(columns=mapping)

df_cat_nat.loc[df_cat_nat['siren'] == 75056, 'siren'] = 200054781

df_cat_nat = duckdb.from_df(df_cat_nat)
df_cat_nat
# Out:
# ┌───────────┬────────────────────────────────────────────────────────────┬────────────┐
# │   siren   │                          nom_epci                          │ nb_cat_nat │
# │   int64   │                          varchar                           │   int64    │
# ├───────────┼────────────────────────────────────────────────────────────┼────────────┤
# │ 200000172 │ CC Faucigny - Glières                                      │         58 │
# │ 200000438 │ CC du Pays de Pontchâteau St-Gildas-des-Bois               │         45 │
# │ 200000545 │ CC des Portes de Romilly sur Seine                         │         31 │
# │ 200000628 │ CC Rhône Lez Provence                                      │         87 │
# │ 200000800 │ CC Coeur de Sologne                                        │         31 │
# │ 200000925 │ CC de la Plaine Dijonnaise                                 │         91 │
# │ 200000933 │ CC Sauldre et Sologne                                      │        111 │
# │ 200004802 │ CC du Pays de Fayence                                      │        111 │
# │ 200005932 │ CC des Portes de Sologne                                   │         62 │
# │ 200005957 │ CC de la Région de Rambervillers                           │        219 │
# │     ·     │               ·                                            │          · │
# │     ·     │               ·                                            │          · │
# │     ·     │               ·                                            │          · │
# │ 249720061 │ CA du Centre de la Martinique                              │         89 │
# │ 249730037 │ CC de l'Ouest Guyanais                                     │          9 │
# │ 249730045 │ CA du Centre Littoral                                      │         30 │
# │ 249730052 │ CC de l'Est Guyanais                                       │          2 │
# │ 249740077 │ CA CIVIS (Communauté Intercommunale des Villes Solidaires) │        144 │
# │ 249740085 │ CA du Sud                                                  │         83 │
# │ 249740093 │ CA Intercommunale de la Réunion Est (CIREST)               │        110 │
# │ 249740101 │ CA Territoire de la Côte Ouest (TCO)                       │         92 │
# │ 249740119 │ CA Intercommunale du Nord de la Réunion (CINOR)            │         80 │
# │ 200054781 │ Paris                                                      │         22 │
# ├───────────┴────────────────────────────────────────────────────────────┴────────────┤
# │ 1266 rows (20 shown)                                                      3 columns │
# └─────────────────────────────────────────────────────────────────────────────────────┘

# %%
query = """
SELECT e.siren,
        e.dept,
        e.total_pop_tot,
    df_cat_nat.nb_cat_nat,
    ROUND(1.0*df_cat_nat.nb_cat_nat / e.superficie_km2, 3) AS cat_nat_per_km2
FROM df_epci_filtered AS e
LEFT JOIN df_cat_nat
ON e.siren = df_cat_nat.siren
"""

df_cat_nat_final = duckdb.sql(query)

# %%
df_cat_nat_final.write_csv("./data/processed/cat_nat_epci.csv")
